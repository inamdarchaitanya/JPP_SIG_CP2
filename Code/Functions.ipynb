# %%
#Function to compare 2 numbers
def Compare(a, b):
    if a > b:
        return f"{a} is greater than {b}"
    elif b > a:
        return f"{b} is greater than {a}"
    else:
        return "Both numbers are equal"

#Function to generate tables in a given range
def GenerateTable(num1,num2):
    for i in range(num1, num2+1):
        print(f"Table of {i}:")
        for j in range(1, 11):
            print(f"{i} x {j} = {i * j}")
        print()  # Blank line for separation
        
#Function to convert celcius to Farenheit
def Convert(celsius):
    fahrenheit = (celsius * 9/5) + 32
    return f"{celsius}°C is equal to {fahrenheit}°F"

#Function to calculate area of a rectangle
def CalculateArea(length, width):
    area = length * width
    return f"The area of the rectangle is {area} square units"

#Function to check if a given number is prime 
def CheckifPrime(number):
    if number <= 1:
        return f"{number} is not a prime number"
    for i in range(2, int(number ** 0.5) + 1):
        if number % i == 0:
            return f"{number} is not a prime number"
    return f"{number} is a prime number"


print(Compare(18,9))
GenerateTable(2,10)
print(Convert(100))
print(CalculateArea(10,20))
print (CheckifPrime(18))
print (CheckifPrime(97))
# Out:
# 18 is greater than 9
# Table of 2:
# 2 x 1 = 2
# 2 x 2 = 4
# 2 x 3 = 6
# 2 x 4 = 8
# 2 x 5 = 10
# 2 x 6 = 12
# 2 x 7 = 14
# 2 x 8 = 16
# 2 x 9 = 18
# 2 x 10 = 20
#
# Table of 3:
# 3 x 1 = 3
# 3 x 2 = 6
# 3 x 3 = 9
# 3 x 4 = 12
# 3 x 5 = 15
# 3 x 6 = 18
# 3 x 7 = 21
# 3 x 8 = 24
# 3 x 9 = 27
# 3 x 10 = 30
#
# Table of 4:
# 4 x 1 = 4
# 4 x 2 = 8
# 4 x 3 = 12
# 4 x 4 = 16
# 4 x 5 = 20
# 4 x 6 = 24
# 4 x 7 = 28
# 4 x 8 = 32
# 4 x 9 = 36
# 4 x 10 = 40
#
# Table of 5:
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
# 5 x 10 = 50
#
# Table of 6:
# 6 x 1 = 6
# 6 x 2 = 12
# 6 x 3 = 18
# 6 x 4 = 24
# 6 x 5 = 30
# 6 x 6 = 36
# 6 x 7 = 42
# 6 x 8 = 48
# 6 x 9 = 54
# 6 x 10 = 60
#
# Table of 7:
# 7 x 1 = 7
# 7 x 2 = 14
# 7 x 3 = 21
# 7 x 4 = 28
# 7 x 5 = 35
# 7 x 6 = 42
# 7 x 7 = 49
# 7 x 8 = 56
# 7 x 9 = 63
# 7 x 10 = 70
#
# Table of 8:
# 8 x 1 = 8
# 8 x 2 = 16
# 8 x 3 = 24
# 8 x 4 = 32
# 8 x 5 = 40
# 8 x 6 = 48
# 8 x 7 = 56
# ...
